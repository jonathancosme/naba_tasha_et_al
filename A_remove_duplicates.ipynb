# %%
import pandas as pd

# %%
input_filename = 'naba_data.csv'
txt_col = "Copy/ PasteÂ An Essay Response of 500 words or less (copy and paste in webform) using the following prompt: Community disruptions such as Covid-19 and other natural disasters can have deep lasting impacts. Discuss a challenge or barrier you have overcome during the Covid-19 pandemic."

dropped_filename = './output_files/naba_data_dropped_rows.csv'
removed_duplicates_filename = './output_files/naba_data_removed_duplicates.csv'

# %% [markdown]
# ## Clean Data

# %%
df = pd.read_csv(input_filename)
df = df.reset_index().rename(columns={'index': 'app_id'}) # add a column for application id, which is just the row number upon initial load
df
# Out:
#      app_id  \
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ..      ...
# 200     200
# 201     201
# 202     202
# 203     203
# 204     204
#
#     Gender:* Required fields are indicated with red symbol Permanent Contact Information  \
# 0                                                 Male
# 1                                               Female
# 2                                               Female
# 3                                               Female
# 4                                                 Male
# ..                                                 ...
# 200                                             Female
# 201                                             Female
# 202                                             Female
# 203                                             Female
# 204                                                NaN
#
#     City (Permanent):* Required fields are indicated with red symbol Permanent Contact Information   \
# 0                                             Brooklyn
# 1                                                Bowie
# 2                                      Chicago Heights
# 3                                              Chicago
# 4                                          Baton Rouge
# ..                                                 ...
# 200                                           Brooklyn
# 201                                           Brooklyn
# 202                                           Valdosta
# 203                                       Jacksonville
# 204                                                NaN
#
#     State (Permanent):* Required fields are indicated with red symbol Permanent Contact Information  \
# 0                                                   NY
# 1                                                   MD
# 2                                                   IL
# 3                                                   IL
# 4                                                   LA
# ..                                                 ...
# 200                                                 NY
# 201                                                 NY
# 202                                                 GA
# 203                                                 FL
# 204                                                NaN
#
#     Zip (Permanent):* Required fields are indicated with red symbol Permanent Contact Information  \
# 0                                                11216
# 1                                                20720
# 2                                                60411
# 3                                                60620
# 4                                                70806
# ..                                                 ...
# 200                                              11210
# 201                                              11212
# 202                                              31601
# 203                                              32221
# 204                                                NaN
#
#     Are you Black? (includes African, African American, Caribbean, etc.)  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 200                                                Yes
# 201                                                Yes
# 202                                                Yes
# 203                                                Yes
# 204                                                NaN
#
#     Preferred Mailing Address  College/University:Academic Profile  \
# 0                   Permanent                 Medgar Evers College
# 1                   Permanent               University of Maryland
# 2                   Permanent  North Carolina A&T State University
# 3                   Permanent            Loyola University Chicago
# 4            Campus/Temporary                Penn State University
# ..                        ...                                  ...
# 200                 Permanent           University at Albany, SUNY
# 201                 Permanent                 Medgar Evers College
# 202                 Permanent            Valdosta State University
# 203          Campus/Temporary               Florida A&M University
# 204                       NaN                                  NaN
#
#     Classification (as of January 2022):Academic Profile  \
# 0                                               Senior
# 1                                             Freshman
# 2                                             Freshman
# 3                                            Sophomore
# 4                                            Sophomore
# ..                                                 ...
# 200                                             Junior
# 201                                             Junior
# 202                                             Junior
# 203                                   Graduate Student
# 204                                                NaN
#
#       Major:Academic Profile  ...  \
# 0                 Accounting  ...
# 1        Business Management  ...
# 2                 Accounting  ...
# 3                 Accounting  ...
# 4                 Accounting  ...
# ..                       ...  ...
# 200  Business Administration  ...
# 201               Accounting  ...
# 202                  Finance  ...
# 203  Business Administration  ...
# 204                      NaN  ...
#
#     Please provide details (i.e. company name, location, etc.)  \
# 0                                                  NaN
# 1    Received internship as a Summer 2022 Discovery...
# 2                                                  NaN
# 3                  Ernst & Young, Chicago, Summer 2022
# 4                                                  NaN
# ..                                                 ...
# 200                          JPMorgan Chase & Co., NYC
# 201                                                NaN
# 202  J.P Morgan Summer 2022, Atlanta office, Summer...
# 203                             Deloitte LLP - Houston
# 204                                                NaN
#
#     I have accepted an internship for the summer of 2022 (June - August)  \
# 0                                                  NaN
# 1                                                  Yes
# 2                                                   No
# 3                                                  Yes
# 4                                                  NaN
# ..                                                 ...
# 200                                                Yes
# 201                                                NaN
# 202                                                Yes
# 203                                                Yes
# 204                                                NaN
#
#     I have accepted an internship for the fall of 2022 (September- December)  \
# 0                                                  NaN
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                  NaN
# ..                                                 ...
# 200                                                 No
# 201                                                NaN
# 202                                                 No
# 203                                                 No
# 204                                                NaN
#
#      Please provide details (i.e. company name, location, etc.).1  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                  Ernst & Young, Chicago, Summer 2022
# 4                                                  NaN
# ..                                                 ...
# 200                          JPMorgan Chase & Co., NYC
# 201                                                NaN
# 202  J.P. Morgan, Middle-Market Bank, Atlanta offic...
# 203                             Deloitte LLP - Houston
# 204                                                NaN
#
#      I have accepted a permanent job offer  \
# 0                                       No
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                       No
# ..                                     ...
# 200                                     No
# 201                                     No
# 202                                     No
# 203                                     No
# 204                                    NaN
#
#     Please provide details (i.e. company name, location, etc.).2  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 200                                                NaN
# 201                                                NaN
# 202                                                NaN
# 203                                                NaN
# 204                                                NaN
#
#     Have you received a CPA Exam Review?  \
# 0                                     No
# 1                                     No
# 2                                     No
# 3                                     No
# 4                                     No
# ..                                   ...
# 200                                   No
# 201                                   No
# 202                                   No
# 203                                   No
# 204                                  NaN
#
#     Which CPA Exam Review have you received?  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 200                                      NaN
# 201                                      NaN
# 202                                      NaN
# 203                                      NaN
# 204                                      NaN
#
#     Copy/ PasteÂ An Essay Response of 500 words or less (copy and paste in webform) using the following prompt: Community disruptions such as Covid-19 and other natural disasters can have deep lasting impacts. Discuss a challenge or barrier you have overcome during the Covid-19 pandemic.  \
# 0    During the early parts of 2020 one of the dead...
# 1    One of the most challenging times has been dur...
# 2    When covid restrictions took place I was just ...
# 3    When the Covid-19 pandemic first began, I was ...
# 4    Community disruptions such as Covid-19 and oth...
# ..                                                 ...
# 200  My name is Wunmi Surakat, a current 1st semest...
# 201  No one expected the Covid- 19 pandemic. Since ...
# 202  During the COVID-19 pandemic, my entire life c...
# 203  The Covid-19 pandemic is something that has af...
# 204                                                NaN
#
#     Recipient
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         Yes
# ..        ...
# 200       NaN
# 201       NaN
# 202       NaN
# 203       Yes
# 204       NaN
#
# [205 rows x 37 columns]

# %% [markdown]
# ## Remove duplicate rows

# %%
df[txt_col] = df[txt_col].astype(str)
df[txt_col] = df[txt_col].str.strip()

# %%
# check for duplicate paragraphs
n_rows = df.shape[0]
print(f"total number of applications: {n_rows}")
n_unq_paras = df[txt_col].drop_duplicates().shape[0]
print(f"total number of UNIQUE paragraphs: {n_unq_paras}")
has_no_duplicate_paras = n_rows == n_unq_paras
print(f"are there no duplicate paragraphs?: {has_no_duplicate_paras}")
# Out:
# total number of applications: 205
# total number of UNIQUE paragraphs: 200
# are there no duplicate paragraphs?: False

# %%
# get a list of duplicate paragraphs
duplicate_paras = df[txt_col].value_counts()[(df[txt_col].value_counts() > 1).values].index

# %%
# get app id of duplicate paragraphs to keep and delete (keep the entry with the least amount of empty values; drop the rest)
app_ids_to_drop = []
app_ids_to_keep = []
for a_duplicate_para in duplicate_paras.values:
    temp_df = df.set_index(txt_col).loc[a_duplicate_para].reset_index().copy()
    temp_df = temp_df.set_index(temp_df.isnull().sum(axis=1).reset_index()['index'].values)
    app_ids_to_drop.extend(temp_df['app_id'][1::].tolist())
    app_ids_to_keep.append(temp_df['app_id'][0])
    print(f"will drop: {app_ids_to_drop}")
    print(f"will keep: {app_ids_to_keep}")
# Out:
# will drop: [177]
# will keep: [176]
# will drop: [177, 175]
# will keep: [176, 174]
# will drop: [177, 175, 204]
# will keep: [176, 174, 148]
# will drop: [177, 175, 204, 134]
# will keep: [176, 174, 148, 133]
# will drop: [177, 175, 204, 134, 89]
# will keep: [176, 174, 148, 133, 88]

# %%
# drop duplicate applications
col_order = df.columns # get initial order of columns

# create a dataframe of the rows to be dropped (because they are diplicates)
df_dups = df.copy() 
df_dups = df_dups[df_dups['app_id'].isin(app_ids_to_drop)].reset_index(drop=True)
df_dups = df_dups[col_order]

# update the dataframe to have duplicate rows removed
df = df[~df['app_id'].isin(app_ids_to_drop)].reset_index(drop=True)
df = df[col_order]

# %%
# check to see if duplication drop was successful 
n_rows = df.shape[0]
print(f"total number of applications: {n_rows}")
n_unq_paras = df[txt_col].drop_duplicates().shape[0]
print(f"total number of UNIQUE paragraphs: {n_unq_paras}")
has_no_duplicate_paras = n_rows == n_unq_paras
print(f"are there no duplicate paragraphs?: {has_no_duplicate_paras}")
# Out:
# total number of applications: 200
# total number of UNIQUE paragraphs: 200
# are there no duplicate paragraphs?: True

# %%
df_dups
# Out:
#    app_id  \
# 0      89
# 1     134
# 2     175
# 3     177
# 4     204
#
#   Gender:* Required fields are indicated with red symbol Permanent Contact Information  \
# 0                                             Female
# 1                                             Female
# 2                                             Female
# 3                                               Male
# 4                                                NaN
#
#   City (Permanent):* Required fields are indicated with red symbol Permanent Contact Information   \
# 0                                          Hockessin
# 1                                            WALTHAM
# 2                                            beckley
# 3                                         Alexandria
# 4                                                NaN
#
#   State (Permanent):* Required fields are indicated with red symbol Permanent Contact Information  \
# 0                                                 DE
# 1                                                 MA
# 2                                                 WV
# 3                                                 VA
# 4                                                NaN
#
#   Zip (Permanent):* Required fields are indicated with red symbol Permanent Contact Information  \
# 0                                              19707
# 1                                               2453
# 2                                              25801
# 3                                              22309
# 4                                                NaN
#
#   Are you Black? (includes African, African American, Caribbean, etc.)  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                NaN
#
#   Preferred Mailing Address College/University:Academic Profile  \
# 0          Campus/Temporary               Goldey-Beacom College
# 1                 Permanent                  Bentley University
# 2          Campus/Temporary                 Bluffton University
# 3                 Permanent             George Mason University
# 4                       NaN                                 NaN
#
#   Classification (as of January 2022):Academic Profile  \
# 0                                             Junior
# 1                                   Graduate Student
# 2                                             Junior
# 3                                             Senior
# 4                                                NaN
#
#                      Major:Academic Profile  ...  \
# 0                                Accounting  ...
# 1  Masters of Business Administration (MBA)  ...
# 2                                Accounting  ...
# 3                                Accounting  ...
# 4                                       NaN  ...
#
#   Please provide details (i.e. company name, location, etc.)  \
# 0          WSFS Bank Summer Intern, PwC Start Intern
# 1  Spotify (Boston), PayPal (Boston), Zoom(Multip...
# 2                                Ernst and Young LLC
# 3                                       PwC and KPMG
# 4                                                NaN
#
#   I have accepted an internship for the summer of 2022 (June - August)  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                NaN
# 4                                                NaN
#
#   I have accepted an internship for the fall of 2022 (September- December)  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                NaN
# 4                                                NaN
#
#    Please provide details (i.e. company name, location, etc.).1  \
# 0  PwC Start Program Summer Intern Philadelphia L...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    I have accepted a permanent job offer  \
# 0                                     No
# 1                                     No
# 2                                     No
# 3                                     No
# 4                                    NaN
#
#   Please provide details (i.e. company name, location, etc.).2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Have you received a CPA Exam Review?  \
# 0                                   No
# 1                                   No
# 2                                   No
# 3                                  Yes
# 4                                  NaN
#
#    Which CPA Exam Review have you received?  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3  Surgent CPA Review and Becker CPA Review
# 4                                       NaN
#
#   Copy/ PasteÂ An Essay Response of 500 words or less (copy and paste in webform) using the following prompt: Community disruptions such as Covid-19 and other natural disasters can have deep lasting impacts. Discuss a challenge or barrier you have overcome during the Covid-19 pandemic.  \
# 0  The challenges I had to overcome during the Co...
# 1  "Mirabel seemed to have life figured out.", "A...
# 2  Covid-19 gave the world an x-ray of the inequa...
# 3  My family was affected by the COVID pandemic. ...
# 4                                                nan
#
#   Recipient
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 37 columns]

# %%
# saved rows that were dropped
df_dups.to_csv(dropped_filename, index=False)

# %%
df
# Out:
#      app_id  \
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ..      ...
# 195     199
# 196     200
# 197     201
# 198     202
# 199     203
#
#     Gender:* Required fields are indicated with red symbol Permanent Contact Information  \
# 0                                                 Male
# 1                                               Female
# 2                                               Female
# 3                                               Female
# 4                                                 Male
# ..                                                 ...
# 195                                               Male
# 196                                             Female
# 197                                             Female
# 198                                             Female
# 199                                             Female
#
#     City (Permanent):* Required fields are indicated with red symbol Permanent Contact Information   \
# 0                                             Brooklyn
# 1                                                Bowie
# 2                                      Chicago Heights
# 3                                              Chicago
# 4                                          Baton Rouge
# ..                                                 ...
# 195                                         Middletown
# 196                                           Brooklyn
# 197                                           Brooklyn
# 198                                           Valdosta
# 199                                       Jacksonville
#
#     State (Permanent):* Required fields are indicated with red symbol Permanent Contact Information  \
# 0                                                   NY
# 1                                                   MD
# 2                                                   IL
# 3                                                   IL
# 4                                                   LA
# ..                                                 ...
# 195                                                 DE
# 196                                                 NY
# 197                                                 NY
# 198                                                 GA
# 199                                                 FL
#
#     Zip (Permanent):* Required fields are indicated with red symbol Permanent Contact Information  \
# 0                                                11216
# 1                                                20720
# 2                                                60411
# 3                                                60620
# 4                                                70806
# ..                                                 ...
# 195                                              19709
# 196                                              11210
# 197                                              11212
# 198                                              31601
# 199                                              32221
#
#     Are you Black? (includes African, African American, Caribbean, etc.)  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 195                                                Yes
# 196                                                Yes
# 197                                                Yes
# 198                                                Yes
# 199                                                Yes
#
#     Preferred Mailing Address  College/University:Academic Profile  \
# 0                   Permanent                 Medgar Evers College
# 1                   Permanent               University of Maryland
# 2                   Permanent  North Carolina A&T State University
# 3                   Permanent            Loyola University Chicago
# 4            Campus/Temporary                Penn State University
# ..                        ...                                  ...
# 195                 Permanent              West Chester University
# 196                 Permanent           University at Albany, SUNY
# 197                 Permanent                 Medgar Evers College
# 198                 Permanent            Valdosta State University
# 199          Campus/Temporary               Florida A&M University
#
#     Classification (as of January 2022):Academic Profile  \
# 0                                               Senior
# 1                                             Freshman
# 2                                             Freshman
# 3                                            Sophomore
# 4                                            Sophomore
# ..                                                 ...
# 195                                   Graduate Student
# 196                                             Junior
# 197                                             Junior
# 198                                             Junior
# 199                                   Graduate Student
#
#                  Major:Academic Profile  ...  \
# 0                            Accounting  ...
# 1                   Business Management  ...
# 2                            Accounting  ...
# 3                            Accounting  ...
# 4                            Accounting  ...
# ..                                  ...  ...
# 195  Masters of Business Administration  ...
# 196             Business Administration  ...
# 197                          Accounting  ...
# 198                             Finance  ...
# 199             Business Administration  ...
#
#     Please provide details (i.e. company name, location, etc.)  \
# 0                                                  NaN
# 1    Received internship as a Summer 2022 Discovery...
# 2                                                  NaN
# 3                  Ernst & Young, Chicago, Summer 2022
# 4                                                  NaN
# ..                                                 ...
# 195  Ernst and Young, Philadelphia, Pa, Financial C...
# 196                          JPMorgan Chase & Co., NYC
# 197                                                NaN
# 198  J.P Morgan Summer 2022, Atlanta office, Summer...
# 199                             Deloitte LLP - Houston
#
#     I have accepted an internship for the summer of 2022 (June - August)  \
# 0                                                  NaN
# 1                                                  Yes
# 2                                                   No
# 3                                                  Yes
# 4                                                  NaN
# ..                                                 ...
# 195                                                Yes
# 196                                                Yes
# 197                                                NaN
# 198                                                Yes
# 199                                                Yes
#
#     I have accepted an internship for the fall of 2022 (September- December)  \
# 0                                                  NaN
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                  NaN
# ..                                                 ...
# 195                                                 No
# 196                                                 No
# 197                                                NaN
# 198                                                 No
# 199                                                 No
#
#      Please provide details (i.e. company name, location, etc.).1  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                  Ernst & Young, Chicago, Summer 2022
# 4                                                  NaN
# ..                                                 ...
# 195  Ernst and Young, Philadelphia, Pa, Financial C...
# 196                          JPMorgan Chase & Co., NYC
# 197                                                NaN
# 198  J.P. Morgan, Middle-Market Bank, Atlanta offic...
# 199                             Deloitte LLP - Houston
#
#      I have accepted a permanent job offer  \
# 0                                       No
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                       No
# ..                                     ...
# 195                                     No
# 196                                     No
# 197                                     No
# 198                                     No
# 199                                     No
#
#     Please provide details (i.e. company name, location, etc.).2  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
#     Have you received a CPA Exam Review?  \
# 0                                     No
# 1                                     No
# 2                                     No
# 3                                     No
# 4                                     No
# ..                                   ...
# 195                                  Yes
# 196                                   No
# 197                                   No
# 198                                   No
# 199                                   No
#
#     Which CPA Exam Review have you received?  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 195                                   Becker
# 196                                      NaN
# 197                                      NaN
# 198                                      NaN
# 199                                      NaN
#
#     Copy/ PasteÂ An Essay Response of 500 words or less (copy and paste in webform) using the following prompt: Community disruptions such as Covid-19 and other natural disasters can have deep lasting impacts. Discuss a challenge or barrier you have overcome during the Covid-19 pandemic.  \
# 0    During the early parts of 2020 one of the dead...
# 1    One of the most challenging times has been dur...
# 2    When covid restrictions took place I was just ...
# 3    When the Covid-19 pandemic first began, I was ...
# 4    Community disruptions such as Covid-19 and oth...
# ..                                                 ...
# 195  There are many issues that are impacting the a...
# 196  My name is Wunmi Surakat, a current 1st semest...
# 197  No one expected the Covid- 19 pandemic. Since ...
# 198  During the COVID-19 pandemic, my entire life c...
# 199  The Covid-19 pandemic is something that has af...
#
#     Recipient
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         Yes
# ..        ...
# 195       Yes
# 196       NaN
# 197       NaN
# 198       NaN
# 199       Yes
#
# [200 rows x 37 columns]

# %%
# save removed duplicates file
df.to_csv(removed_duplicates_filename, index=False)
